# %% [markdown]
# Predicting wine quality: Here I use importance for Feature selection  and Random search for searching method. Smote and random under sampler are used for resampling

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
red_wine=pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-red.csv", sep=';')
print(red_wine.shape)
# Out:
# (1599, 12)

# %% [markdown]
# Add a feature regarding quality

# %%
red_wine["wine_quality"]=red_wine['quality'].apply(lambda x: 'low' if x <= 5 else 'medium' if x <=7
else 'high')
red_wine['wine_quality']= pd.Categorical(red_wine['wine_quality'], categories=['low','medium','high'])
red_wine=red_wine.drop_duplicates()
red_wine
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 5               7.4             0.660         0.00             1.8      0.075
# ...             ...               ...          ...             ...        ...
# 1593            6.8             0.620         0.08             1.9      0.068
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 5                    13.0                  40.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1593                 28.0                  38.0  0.99651  3.42       0.82
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality wine_quality
# 0         9.4        5          low
# 1         9.8        5          low
# 2         9.8        5          low
# 3         9.8        6       medium
# 5         9.4        5          low
# ...       ...      ...          ...
# 1593      9.5        6       medium
# 1594     10.5        5          low
# 1595     11.2        6       medium
# 1597     10.2        5          low
# 1598     11.0        6       medium
#
# [1359 rows x 13 columns]

# %%
red_wine.hist(figsize=(12,6),layout=(3,5))
# Out:
# array([[<AxesSubplot:title={'center':'fixed acidity'}>,
#         <AxesSubplot:title={'center':'volatile acidity'}>,
#         <AxesSubplot:title={'center':'citric acid'}>,
#         <AxesSubplot:title={'center':'residual sugar'}>,
#         <AxesSubplot:title={'center':'chlorides'}>],
#        [<AxesSubplot:title={'center':'free sulfur dioxide'}>,
#         <AxesSubplot:title={'center':'total sulfur dioxide'}>,
#         <AxesSubplot:title={'center':'density'}>,
#         <AxesSubplot:title={'center':'pH'}>,
#         <AxesSubplot:title={'center':'sulphates'}>],
#        [<AxesSubplot:title={'center':'alcohol'}>,
#         <AxesSubplot:title={'center':'quality'}>, <AxesSubplot:>,
#         <AxesSubplot:>, <AxesSubplot:>]], dtype=object)

# %% [markdown]
# As it is seen above most of features are right-skewed. I transform the data to log to bring the destribution of data closeer to normal.

# %%
red_wine_t=np.log((red_wine[red_wine.columns[:-2]])+0.00005)
red_wine_t["wine_quality"]=red_wine["wine_quality"]
red_wine_t.hist(figsize=(12,6),layout=(3,5))
# Out:
# array([[<AxesSubplot:title={'center':'fixed acidity'}>,
#         <AxesSubplot:title={'center':'volatile acidity'}>,
#         <AxesSubplot:title={'center':'citric acid'}>,
#         <AxesSubplot:title={'center':'residual sugar'}>,
#         <AxesSubplot:title={'center':'chlorides'}>],
#        [<AxesSubplot:title={'center':'free sulfur dioxide'}>,
#         <AxesSubplot:title={'center':'total sulfur dioxide'}>,
#         <AxesSubplot:title={'center':'density'}>,
#         <AxesSubplot:title={'center':'pH'}>,
#         <AxesSubplot:title={'center':'sulphates'}>],
#        [<AxesSubplot:title={'center':'alcohol'}>, <AxesSubplot:>,
#         <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>]], dtype=object)

# %% [markdown]
# Plot pie chart to see the number of different wine qualities

# %%
plt.pie(red_wine_t['wine_quality'].value_counts(), labels=red_wine_t['wine_quality'].unique(), autopct='%.2f')
# Out:
# ([<matplotlib.patches.Wedge at 0x7faa3264d760>,
#   <matplotlib.patches.Wedge at 0x7faa3264d550>,
#   <matplotlib.patches.Wedge at 0x7faa32618d30>],
#  [Text(-0.05718854349591392, 1.0985123897766544, 'low'),
#   Text(0.013985176224340375, -1.0999110940644132, 'medium'),
#   Text(1.0991506836631655, -0.04321775795660954, 'high')],
#  [Text(-0.031193750997771226, 0.5991885762418114, '51.66'),
#   Text(0.007628277940549294, -0.5999515058533162, '47.09'),
#   Text(0.5995367365435448, -0.02357332252178702, '1.25')])

# %%
red_wine_t['wine_quality']=np.where(red_wine_t['wine_quality']=='high', 2,red_wine_t['wine_quality'] )
red_wine_t['wine_quality']=np.where(red_wine_t['wine_quality']=='medium', 1,red_wine_t['wine_quality'] )
red_wine_t['wine_quality']=np.where(red_wine_t['wine_quality']=='low', 0,red_wine_t['wine_quality'] )
red_wine_t['wine_quality']=red_wine_t['wine_quality'].astype('int32')
red_wine_t['wine_quality'].value_counts()
# Out:
# 1    702
# 0    640
# 2     17
# Name: wine_quality, dtype: int64

# %% [markdown]
# Split data

# %%
from sklearn.model_selection import train_test_split
x, y=red_wine_t[red_wine_t.columns[:-2]], red_wine_t[red_wine_t.columns[-1]]
x=np.array(x)
y=np.array(y)
X_train,X_test,y_train,y_test=train_test_split(x,y, test_size=0.3,shuffle=True, random_state=42,stratify=y)

# %% [markdown]
# Create pipelines to use in nested cross validation

# %%
from sklearn.ensemble import  RandomForestClassifier, AdaBoostClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from xgboost import XGBClassifier as Xgb
from sklearn.neighbors import KNeighborsClassifier
from lightgbm import LGBMClassifier as LighGB
from sklearn.svm import SVC
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.model_selection import RandomizedSearchCV
from sklearn.feature_selection import SelectFromModel
from xgboost import XGBClassifier
from catboost import CatBoostRegressor
from sklearn.ensemble import GradientBoostingClassifier
from imblearn.over_sampling import BorderlineSMOTE, SMOTE
from imblearn.under_sampling import RandomUnderSampler
from sklearn.metrics import matthews_corrcoef, f1_score, confusion_matrix, make_scorer, balanced_accuracy_score
from imblearn.pipeline import Pipeline, make_pipeline
from sklearn.model_selection import cross_validate, StratifiedKFold, RepeatedStratifiedKFold
from sklearn.model_selection import learning_curve
from sklearn.ensemble import HistGradientBoostingClassifier
from sklearnex import patch_sklearn 
from pandas import MultiIndex, Int64Index
patch_sklearn()

# initiakising classifiers

m1 = LogisticRegression(multi_class='multinomial',
                          solver='newton-cg',
                          random_state=42)
m2 = AdaBoostClassifier(random_state=42)
m3 = DecisionTreeClassifier(random_state=42)
m4 = LighGB(random_state=1)
m5 = RandomForestClassifier(random_state=42)
m6= SVC()
m7=XGBClassifier(use_label_encoder=False,disable_default_eval_metric =True,random_state=42)

m8=GradientBoostingClassifier(random_state=42)



# define pipeline
# Building the pipelines
pipe1 = Pipeline([('oversample', SMOTE()),('undersample', RandomUnderSampler()),('import',SelectFromModel(m1)),
                  ('m1', m1)])

pipe2 = Pipeline([('oversample', SMOTE()),('undersample', RandomUnderSampler()),('import',SelectFromModel(m2)),
                  ('m2', m2)])
                
pipe3 = Pipeline([('oversample', SMOTE()),('undersample', RandomUnderSampler()),('import',SelectFromModel(m3)),
                  ('m3', m3)])

pipe4 = Pipeline([('oversample', SMOTE()),('undersample', RandomUnderSampler()),('import',SelectFromModel(m4)),
                  ('m4', m4)])

pipe5 = Pipeline([('oversample', SMOTE()),('undersample', RandomUnderSampler()),('import',SelectFromModel(m5)),
                  ('m5', m5)])

pipe6 = Pipeline([('oversample', SMOTE()),('undersample', RandomUnderSampler()),('import',SelectFromModel(m6)),
                  ('m6', m6)])

pipe7 = Pipeline([('oversample', SMOTE()),('undersample', RandomUnderSampler()),('import',SelectFromModel(m7)),
                  ('m7', m7)])

pipe8 = Pipeline([('oversample', SMOTE()),('undersample', RandomUnderSampler()),('import',SelectFromModel(m8)),
                  ('m8', m8)])

# Setting up the parameter grids
par1 = [{"oversample__sampling_strategy":['auto','minority'], 
        "import__max_features": [4,6,8,10], 'm1__penalty': ['l2']
                ,'m1__C': np.power(10., np.arange(-4, 4))}]

par2 = [{"oversample__sampling_strategy":['auto','minority'], 
                "import__max_features": [4,6,8,10],"m2__n_estimators":[50,100,200,400,600], 
"m2__learning_rate": [0.01,0.001,0.1,0.2]}]

par3 = [{ "oversample__sampling_strategy":['auto','minority'], 
                "import__max_features": [4,6,8,10], "m3__criterion": ["gini", "entropy"],
"m3__splitter": ["best", "random"], "m3__max_depth": [None, 5,7,12,20]}]  

par4 = [{"oversample__sampling_strategy":['auto','minority'], 
                "import__max_features": [4,5,6,7,8,9], 
"m4__max_depth": [-1,5,8], "m4__n_estimators": [100,300,500,30,700],
"m4__learning_rate": [1,2,4], "m4__subsample_for_bin":[500,1000,10000,200000]}]

par5 = [{"oversample__sampling_strategy":['auto','minority'], 
                "import__max_features": [4,6,8,10],  "m5__max_depth": [None,5,8,12,20],
              "m5__n_estimators" :[100,300,50,400,600],
              "m5__criterion": ["gini","entropy"],
              "m5__min_samples_split": [2,4,6],"m5__min_samples_leaf": [1,2,4,5]}]
 
par6 = [{"oversample__sampling_strategy":['auto','minority'], 
                "import__max_features": [8,10],  "m6__C": [1,5],
              "m6__gamma" :['scale','auto', 3], "m6__tol": [0.001,0.0001]}]


par7 = [{"oversample__sampling_strategy":['auto','minority'], 
                "import__max_features": [4,6,8,10],  "m7__max_depth": [3,5,8],
              "m7__n_estimators" :[100,300,50,400,600],"m7__learning_rate" :[0.1,0.01,0.02] }]


par8 = [{"oversample__sampling_strategy":['auto','minority'], 
                "import__max_features": [4,6,8,10],  "m8__max_depth": [3,5,8],
              "m8__n_estimators" :[100,300,50,400,600],"m8__learning_rate" :[0.1,0.01,0.02]}]
# Out:
# Intel(R) Extension for Scikit-learn* enabled (https://github.com/intel/scikit-learn-intelex)

# %% [markdown]
# Creat inner CV

# %%
pipe=[pipe1,pipe2,pipe3,pipe4,pipe5,pipe7,pipe8]
par_grid=[par1,par2,par3,par4,par5,par7,par8]
gcv_all=[]
f1 = make_scorer(f1_score , average='macro')

inner_cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
for i in range(len(pipe)):
    gcv = RandomizedSearchCV(estimator=pipe[i],
                        param_distributions=par_grid[i],
                        scoring='balanced_accuracy',
                        n_jobs=-1,
                        n_iter=30,
                        cv=inner_cv,
                        verbose=0,
                        refit=True)
    gcv_all.append(gcv)

# %% [markdown]
# Function for ploting learning curves

# %%
# Plot learning curve
def plot_learning_curve(estimator, title, X, y, ylim=None, cv=None,
                        n_jobs=-1, train_sizes=np.linspace(.1, 1.0, 20)):
    """
    Generate a simple plot of the test and traning learning curve.

    Parameters
    ----------
    estimator : object type that implements the "fit" and "predict" methods
        An object of that type which is cloned for each validation.

    title : string
        Title for the chart.

    X : array-like, shape (n_samples, n_features)
        Training vector, where n_samples is the number of samples and
        n_features is the number of features.

    y : array-like, shape (n_samples) or (n_samples, n_features), optional
        Target relative to X for classification or regression;
        None for unsupervised learning.

    ylim : tuple, shape (ymin, ymax), optional
        Defines minimum and maximum yvalues plotted.

    cv : integer, cross-validation generator, optional
        If an integer is passed, it is the number of folds (defaults to 3).
        Specific cross-validation objects can be passed, see
        sklearn.cross_validation module for the list of possible objects

    n_jobs : integer, optional
        Number of jobs to run in parallel (default 1).
        
    x1 = np.linspace(0, 10, 8, endpoint=True) produces
        8 evenly spaced points in the range 0 to 10
    """
    
    
    plt.figure()
    plt.title(title)
    if ylim is not None:
        plt.ylim(*ylim)
        
    plt.xlabel("Training examples")
    plt.ylabel("Score")
    train_sizes, train_scores, test_scores = learning_curve(
        estimator, X, y, cv=cv, n_jobs=n_jobs, train_sizes=train_sizes, scoring= "balanced_accuracy")
    train_scores_mean = np.mean(train_scores, axis=1)
    train_scores_std = np.std(train_scores, axis=1)
    test_scores_mean = np.mean(test_scores, axis=1)
    test_scores_std = np.std(test_scores, axis=1)
    plt.grid()

    plt.fill_between(train_sizes, train_scores_mean - train_scores_std,
                     train_scores_mean + train_scores_std, alpha=0.1,
                     color="r")
    plt.fill_between(train_sizes, test_scores_mean - test_scores_std,
                     test_scores_mean + test_scores_std, alpha=0.1, color="g")
    plt.plot(train_sizes, train_scores_mean, 'o-', color="r",
             label="Training score")
    plt.plot(train_sizes, test_scores_mean, 'o-', color="g",
             label="Cross-validation score")

    plt.legend(loc="best")
    return plt

# %%
def con(y_test,pred_rfc):
    labels = np.unique(y_test)
    a = confusion_matrix(y_test, pred_rfc)
    a = pd.DataFrame(a, index=("low", "medium", "high"), columns=("low", "medium", "high"))
    display(a)

# %% [markdown]
# Out CV + plotting learning curves

# %%
import warnings
warnings.simplefilter('ignore')
final_scores = []
final_mean_score=[]
final_std_score=[]


outer_cv = StratifiedKFold(n_splits=10, shuffle=True, random_state=0)
name=['LogisticRegression', 'AdaBoostClassifier','DecisionTreeClassifier'
,'LighGB', 'RandomForestClassifier', 'XGBClassifier','GradientBoostingClassifier'] 



count=0   
for gcv_out in gcv_all:  
    print(80*'_.')
    print('\n ', name[count] )  
    for train_idx, test_idx in outer_cv.split(X_train, y_train): 
        gcv_out.fit(X_train[train_idx], y_train[train_idx]) # run inner loop hyperparam tuning
        pr=gcv_out.predict(X_train[test_idx]) 
        print('\n\n Score of gcv_out prediction %.2f%%' % ((balanced_accuracy_score(pr, y_train[test_idx]))*100))


        print('        Best parameters in inner CV:', gcv_out.best_params_)
        
    
        final_scores.append((balanced_accuracy_score(gcv_out.best_estimator_.predict(X_train[test_idx]), y_train[test_idx])*100)) 
  
        print('       Score of best estimator prediction %.2f%%' % final_scores[-1])
        model=gcv_out.best_estimator_.fit(X_train[train_idx], y_train[train_idx])





    
    print('\n    Outer Loop:')
    print('        balanced accuracy score %.2f%% +/- %.2f' % 
                (np.mean(final_scores) , np.std(final_scores) ))
    final_mean_score.append(np.mean(final_scores) )
    final_std_score.append(np.std(final_scores) )

    plot_learning_curve(estimator = gcv_out.best_estimator_,title = "{} learning curve ".format(name[count]),
                    X = X_train, y = y_train, cv = 10)
    plt.show()
    train_sizes, train_scores, test_scores = learning_curve(
    gcv_out.best_estimator_, X = X_train, y = y_train, cv=5, n_jobs=-1, train_sizes=np.linspace(.1, 1.0, 5), scoring= "balanced_accuracy")
 
    count+=1
# Out:
# _._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._.
#
#   LogisticRegression
#
#
#  Score of gcv_out prediction 49.82%
#         Best parameters in inner CV: {'oversample__sampling_strategy': 'auto', 'm1__penalty': 'l2', 'm1__C': 100.0, 'import__max_features': 8}
#        Score of best estimator prediction 49.82%
#
#
#  Score of gcv_out prediction 45.07%
#         Best parameters in inner CV: {'oversample__sampling_strategy': 'auto', 'm1__penalty': 'l2', 'm1__C': 0.001, 'import__max_features': 8}
#        Score of best estimator prediction 45.07%
#
#
#  Score of gcv_out prediction 43.74%
#         Best parameters in inner CV: {'oversample__sampling_strategy': 'auto', 'm1__penalty': 'l2', 'm1__C': 0.1, 'import__max_features': 8}
#        Score of best estimator prediction 43.74%
#
#
#  Score of gcv_out prediction 54.72%
#         Best parameters in inner CV: {'oversample__sampling_strategy': 'auto', 'm1__penalty': 'l2', 'm1__C': 0.01, 'import__max_features': 6}
#        Score of best estimator prediction 54.72%
#
#
#  Score of gcv_out prediction 35.16%
#         Best parameters in inner CV: {'oversample__sampling_strategy': 'auto', 'm1__penalty': 'l2', 'm1__C': 0.1, 'import__max_features': 8}
#        Score of best estimator prediction 35.16%
#
#
#  Score of gcv_out prediction 42.31%
#         Best parameters in inner CV: {'oversample__sampling_strategy': 'auto', 'm1__penalty': 'l2', 'm1__C': 0.01, 'import__max_features': 10}
#        Score of best estimator prediction 42.31%
#
#
#  Score of gcv_out prediction 50.67%
#         Best parameters in inner CV: {'oversample__sampling_strategy': 'auto', 'm1__penalty': 'l2', 'm1__C': 0.01, 'import__max_features': 8}
#        Score of best estimator prediction 50.67%
#
#
#  Score of gcv_out prediction 41.09%
#         Best parameters in inner CV: {'oversample__sampling_strategy': 'auto', 'm1__penalty': 'l2', 'm1__C': 1.0, 'import__max_features': 4}
#        Score of best estimator prediction 41.09%
#
#
#  Score of gcv_out prediction 27.87%
#         Best parameters in inner CV: {'oversample__sampling_strategy': 'auto', 'm1__penalty': 'l2', 'm1__C': 0.001, 'import__max_features': 6}
#        Score of best estimator prediction 27.87%
#
#
#  Score of gcv_out prediction 33.07%
#         Best parameters in inner CV: {'oversample__sampling_strategy': 'auto', 'm1__penalty': 'l2', 'm1__C': 0.01, 'import__max_features': 6}
#        Score of best estimator prediction 33.07%
#
#     Outer Loop:
#         balanced accuracy score 42.35% +/- 7.98
# _._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._.
#
#   AdaBoostClassifier
#
#
#  Score of gcv_out prediction 49.72%
#         Best parameters in inner CV: {'oversample__sampling_strategy': 'auto', 'm2__n_estimators': 200, 'm2__learning_rate': 0.01, 'import__max_features': 4}
#        Score of best estimator prediction 49.72%
#
#
#  Score of gcv_out prediction 37.54%
#         Best parameters in inner CV: {'oversample__sampling_strategy': 'auto', 'm2__n_estimators': 400, 'm2__learning_rate': 0.001, 'import__max_features': 10}
#        Score of best estimator prediction 37.54%
#
#
#  Score of gcv_out prediction 40.89%
#         Best parameters in inner CV: {'oversample__sampling_strategy': 'auto', 'm2__n_estimators': 400, 'm2__learning_rate': 0.001, 'import__max_features': 6}
#        Score of best estimator prediction 40.89%
#
#
#  Score of gcv_out prediction 28.84%
#         Best parameters in inner CV: {'oversample__sampling_strategy': 'auto', 'm2__n_estimators': 50, 'm2__learning_rate': 0.001, 'import__max_features': 8}
#        Score of best estimator prediction 28.84%
#
#
#  Score of gcv_out prediction 42.41%
#         Best parameters in inner CV: {'oversample__sampling_strategy': 'auto', 'm2__n_estimators': 200, 'm2__learning_rate': 0.001, 'import__max_features': 4}
#        Score of best estimator prediction 42.41%
#
#
#  Score of gcv_out prediction 42.70%
#         Best parameters in inner CV: {'oversample__sampling_strategy': 'auto', 'm2__n_estimators': 50, 'm2__learning_rate': 0.01, 'import__max_features': 6}
#        Score of best estimator prediction 42.70%
#
#
#  Score of gcv_out prediction 33.44%
#         Best parameters in inner CV: {'oversample__sampling_strategy': 'auto', 'm2__n_estimators': 100, 'm2__learning_rate': 0.001, 'import__max_features': 8}
#        Score of best estimator prediction 33.44%
#
#
#  Score of gcv_out prediction 44.67%
#         Best parameters in inner CV: {'oversample__sampling_strategy': 'auto', 'm2__n_estimators': 50, 'm2__learning_rate': 0.1, 'import__max_features': 10}
#        Score of best estimator prediction 44.67%
#
#
#  Score of gcv_out prediction 44.14%
#         Best parameters in inner CV: {'oversample__sampling_strategy': 'auto', 'm2__n_estimators': 400, 'm2__learning_rate': 0.001, 'import__max_features': 10}
#        Score of best estimator prediction 44.14%
#
#
#  Score of gcv_out prediction 43.00%
#         Best parameters in inner CV: {'oversample__sampling_strategy': 'auto', 'm2__n_estimators': 50, 'm2__learning_rate': 0.1, 'import__max_features': 6}
#        Score of best estimator prediction 43.00%
#
#     Outer Loop:
#         balanced accuracy score 41.54% +/- 6.98
# _._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._.
#
#   DecisionTreeClassifier
#
#
#  Score of gcv_out prediction 42.05%
#         Best parameters in inner CV: {'oversample__sampling_strategy': 'auto', 'm3__splitter': 'random', 'm3__max_depth': None, 'm3__criterion': 'entropy', 'import__max_features': 8}
#        Score of best estimator prediction 42.05%
#
#
#  Score of gcv_out prediction 38.95%
#         Best parameters in inner CV: {'oversample__sampling_strategy': 'auto', 'm3__splitter': 'random', 'm3__max_depth': 12, 'm3__criterion': 'entropy', 'import__max_features': 8}
#        Score of best estimator prediction 38.95%
#
#
#  Score of gcv_out prediction 43.66%
#         Best parameters in inner CV: {'oversample__sampling_strategy': 'auto', 'm3__splitter': 'random', 'm3__max_depth': 7, 'm3__criterion': 'entropy', 'import__max_features': 10}
#        Score of best estimator prediction 43.66%
#
#
#  Score of gcv_out prediction 50.14%
#         Best parameters in inner CV: {'oversample__sampling_strategy': 'auto', 'm3__splitter': 'best', 'm3__max_depth': 7, 'm3__criterion': 'entropy', 'import__max_features': 10}
#        Score of best estimator prediction 50.14%
#
#
#  Score of gcv_out prediction 39.14%
#         Best parameters in inner CV: {'oversample__sampling_strategy': 'auto', 'm3__splitter': 'best', 'm3__max_depth': 5, 'm3__criterion': 'gini', 'import__max_features': 10}
#        Score of best estimator prediction 39.14%
#
#
#  Score of gcv_out prediction 41.27%
#         Best parameters in inner CV: {'oversample__sampling_strategy': 'auto', 'm3__splitter': 'best', 'm3__max_depth': 5, 'm3__criterion': 'entropy', 'import__max_features': 10}
#        Score of best estimator prediction 41.27%
#
#
#  Score of gcv_out prediction 44.49%
#         Best parameters in inner CV: {'oversample__sampling_strategy': 'auto', 'm3__splitter': 'best', 'm3__max_depth': 5, 'm3__criterion': 'entropy', 'import__max_features': 8}
#        Score of best estimator prediction 44.49%
#
#
#  Score of gcv_out prediction 37.90%
#         Best parameters in inner CV: {'oversample__sampling_strategy': 'auto', 'm3__splitter': 'random', 'm3__max_depth': 12, 'm3__criterion': 'gini', 'import__max_features': 10}
#        Score of best estimator prediction 37.90%
#
#
#  Score of gcv_out prediction 44.96%
#         Best parameters in inner CV: {'oversample__sampling_strategy': 'auto', 'm3__splitter': 'random', 'm3__max_depth': 7, 'm3__criterion': 'entropy', 'import__max_features': 10}
#        Score of best estimator prediction 44.96%
#
#
#  Score of gcv_out prediction 43.47%
#         Best parameters in inner CV: {'oversample__sampling_strategy': 'auto', 'm3__splitter': 'best', 'm3__max_depth': 7, 'm3__criterion': 'entropy', 'import__max_features': 6}
#        Score of best estimator prediction 43.47%
#
#     Outer Loop:
#         balanced accuracy score 41.90% +/- 6.05
# _._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._.
#
#   LighGB
#
#
#  Score of gcv_out prediction 52.84%
#         Best parameters in inner CV: {'oversample__sampling_strategy': 'auto', 'm4__subsample_for_bin': 500, 'm4__n_estimators': 300, 'm4__max_depth': 8, 'm4__learning_rate': 1, 'import__max_features': 9}
#        Score of best estimator prediction 52.84%
#
#
#  Score of gcv_out prediction 39.66%
#         Best parameters in inner CV: {'oversample__sampling_strategy': 'auto', 'm4__subsample_for_bin': 500, 'm4__n_estimators': 500, 'm4__max_depth': -1, 'm4__learning_rate': 4, 'import__max_features': 6}
#        Score of best estimator prediction 39.66%
#
#
#  Score of gcv_out prediction 29.12%
#         Best parameters in inner CV: {'oversample__sampling_strategy': 'auto', 'm4__subsample_for_bin': 10000, 'm4__n_estimators': 30, 'm4__max_depth': -1, 'm4__learning_rate': 2, 'import__max_features': 7}
#        Score of best estimator prediction 29.12%
#
#
#  Score of gcv_out prediction 43.30%
#         Best parameters in inner CV: {'oversample__sampling_strategy': 'auto', 'm4__subsample_for_bin': 200000, 'm4__n_estimators': 30, 'm4__max_depth': 8, 'm4__learning_rate': 1, 'import__max_features': 7}
#        Score of best estimator prediction 43.30%
#
#
#  Score of gcv_out prediction 33.78%
#         Best parameters in inner CV: {'oversample__sampling_strategy': 'auto', 'm4__subsample_for_bin': 200000, 'm4__n_estimators': 500, 'm4__max_depth': 5, 'm4__learning_rate': 2, 'import__max_features': 8}
#        Score of best estimator prediction 33.78%
#
#
#  Score of gcv_out prediction 41.11%
#         Best parameters in inner CV: {'oversample__sampling_strategy': 'auto', 'm4__subsample_for_bin': 10000, 'm4__n_estimators': 30, 'm4__max_depth': -1, 'm4__learning_rate': 2, 'import__max_features': 4}
#        Score of best estimator prediction 41.11%
#
#
#  Score of gcv_out prediction 76.57%
#         Best parameters in inner CV: {'oversample__sampling_strategy': 'auto', 'm4__subsample_for_bin': 10000, 'm4__n_estimators': 100, 'm4__max_depth': -1, 'm4__learning_rate': 1, 'import__max_features': 7}
#        Score of best estimator prediction 76.57%
#
#
#  Score of gcv_out prediction 41.78%
#         Best parameters in inner CV: {'oversample__sampling_strategy': 'auto', 'm4__subsample_for_bin': 500, 'm4__n_estimators': 300, 'm4__max_depth': 8, 'm4__learning_rate': 1, 'import__max_features': 5}
#        Score of best estimator prediction 41.78%
#
#
#  Score of gcv_out prediction 45.47%
#         Best parameters in inner CV: {'oversample__sampling_strategy': 'auto', 'm4__subsample_for_bin': 10000, 'm4__n_estimators': 300, 'm4__max_depth': -1, 'm4__learning_rate': 1, 'import__max_features': 7}
#        Score of best estimator prediction 45.47%
#
#
#  Score of gcv_out prediction 44.27%
#         Best parameters in inner CV: {'oversample__sampling_strategy': 'auto', 'm4__subsample_for_bin': 200000, 'm4__n_estimators': 100, 'm4__max_depth': -1, 'm4__learning_rate': 1, 'import__max_features': 4}
#        Score of best estimator prediction 44.27%
#
#     Outer Loop:
#         balanced accuracy score 42.62% +/- 8.15
# _._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._.
#
#   RandomForestClassifier
#
#
#  Score of gcv_out prediction 50.90%
#         Best parameters in inner CV: {'oversample__sampling_strategy': 'auto', 'm5__n_estimators': 300, 'm5__min_samples_split': 6, 'm5__min_samples_leaf': 4, 'm5__max_depth': 12, 'm5__criterion': 'entropy', 'import__max_features': 4}
#        Score of best estimator prediction 50.90%
#
#
#  Score of gcv_out prediction 45.67%
#         Best parameters in inner CV: {'oversample__sampling_strategy': 'auto', 'm5__n_estimators': 600, 'm5__min_samples_split': 4, 'm5__min_samples_leaf': 5, 'm5__max_depth': 5, 'm5__criterion': 'entropy', 'import__max_features': 6}
#        Score of best estimator prediction 45.67%
#
#
#  Score of gcv_out prediction 41.71%
#         Best parameters in inner CV: {'oversample__sampling_strategy': 'auto', 'm5__n_estimators': 400, 'm5__min_samples_split': 6, 'm5__min_samples_leaf': 5, 'm5__max_depth': 5, 'm5__criterion': 'gini', 'import__max_features': 4}
#        Score of best estimator prediction 41.71%
#
#
#  Score of gcv_out prediction 61.83%
#         Best parameters in inner CV: {'oversample__sampling_strategy': 'auto', 'm5__n_estimators': 50, 'm5__min_samples_split': 4, 'm5__min_samples_leaf': 1, 'm5__max_depth': 5, 'm5__criterion': 'gini', 'import__max_features': 4}
#        Score of best estimator prediction 61.83%
#
#
#  Score of gcv_out prediction 48.10%
#         Best parameters in inner CV: {'oversample__sampling_strategy': 'auto', 'm5__n_estimators': 50, 'm5__min_samples_split': 4, 'm5__min_samples_leaf': 5, 'm5__max_depth': 5, 'm5__criterion': 'entropy', 'import__max_features': 4}
#        Score of best estimator prediction 48.10%
#
#
#  Score of gcv_out prediction 42.74%
#         Best parameters in inner CV: {'oversample__sampling_strategy': 'auto', 'm5__n_estimators': 50, 'm5__min_samples_split': 2, 'm5__min_samples_leaf': 2, 'm5__max_depth': None, 'm5__criterion': 'entropy', 'import__max_features': 6}
#        Score of best estimator prediction 42.74%
#
#
#  Score of gcv_out prediction 45.87%
#         Best parameters in inner CV: {'oversample__sampling_strategy': 'auto', 'm5__n_estimators': 300, 'm5__min_samples_split': 2, 'm5__min_samples_leaf': 5, 'm5__max_depth': 5, 'm5__criterion': 'entropy', 'import__max_features': 8}
#        Score of best estimator prediction 45.87%
#
#
#  Score of gcv_out prediction 45.88%
#         Best parameters in inner CV: {'oversample__sampling_strategy': 'auto', 'm5__n_estimators': 300, 'm5__min_samples_split': 6, 'm5__min_samples_leaf': 4, 'm5__max_depth': 5, 'm5__criterion': 'gini', 'import__max_features': 4}
#        Score of best estimator prediction 45.88%
#
#
#  Score of gcv_out prediction 41.21%
#         Best parameters in inner CV: {'oversample__sampling_strategy': 'auto', 'm5__n_estimators': 100, 'm5__min_samples_split': 4, 'm5__min_samples_leaf': 1, 'm5__max_depth': None, 'm5__criterion': 'gini', 'import__max_features': 4}
#        Score of best estimator prediction 41.21%
#
#
#  Score of gcv_out prediction 45.47%
#         Best parameters in inner CV: {'oversample__sampling_strategy': 'auto', 'm5__n_estimators': 100, 'm5__min_samples_split': 4, 'm5__min_samples_leaf': 5, 'm5__max_depth': 5, 'm5__criterion': 'gini', 'import__max_features': 10}
#        Score of best estimator prediction 45.47%
#
#     Outer Loop:
#         balanced accuracy score 43.48% +/- 7.91
# _._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._.
#
#   XGBClassifier
# /Users/marziehbaes/opt/anaconda3/lib/python3.9/site-packages/xgboost/compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index
# /Users/marziehbaes/opt/anaconda3/lib/python3.9/site-packages/xgboost/compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index
# /Users/marziehbaes/opt/anaconda3/lib/python3.9/site-packages/xgboost/compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index
# /Users/marziehbaes/opt/anaconda3/lib/python3.9/site-packages/xgboost/compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index
# /Users/marziehbaes/opt/anaconda3/lib/python3.9/site-packages/xgboost/compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index
# /Users/marziehbaes/opt/anaconda3/lib/python3.9/site-packages/xgboost/compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index
# /Users/marziehbaes/opt/anaconda3/lib/python3.9/site-packages/xgboost/compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index
# /Users/marziehbaes/opt/anaconda3/lib/python3.9/site-packages/xgboost/compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index
#  Score of gcv_out prediction 53.03%
#         Best parameters in inner CV: {'oversample__sampling_strategy': 'auto', 'm7__n_estimators': 50, 'm7__max_depth': 3, 'm7__learning_rate': 0.01, 'import__max_features': 10}
#        Score of best estimator prediction 53.03%
#
#
#  Score of gcv_out prediction 39.60%
#         Best parameters in inner CV: {'oversample__sampling_strategy': 'auto', 'm7__n_estimators': 300, 'm7__max_depth': 5, 'm7__learning_rate': 0.01, 'import__max_features': 10}
#        Score of best estimator prediction 39.60%
#
#
#  Score of gcv_out prediction 45.09%
#         Best parameters in inner CV: {'oversample__sampling_strategy': 'auto', 'm7__n_estimators': 100, 'm7__max_depth': 3, 'm7__learning_rate': 0.01, 'import__max_features': 10}
#        Score of best estimator prediction 45.09%
#
#
#  Score of gcv_out prediction 45.82%
#         Best parameters in inner CV: {'oversample__sampling_strategy': 'auto', 'm7__n_estimators': 300, 'm7__max_depth': 5, 'm7__learning_rate': 0.02, 'import__max_features': 6}
#        Score of best estimator prediction 45.82%
#
#
#  Score of gcv_out prediction 36.17%
#         Best parameters in inner CV: {'oversample__sampling_strategy': 'auto', 'm7__n_estimators': 400, 'm7__max_depth': 3, 'm7__learning_rate': 0.01, 'import__max_features': 6}
#        Score of best estimator prediction 36.17%
#
#
#  Score of gcv_out prediction 42.48%
#         Best parameters in inner CV: {'oversample__sampling_strategy': 'auto', 'm7__n_estimators': 50, 'm7__max_depth': 8, 'm7__learning_rate': 0.01, 'import__max_features': 10}
#        Score of best estimator prediction 42.48%
#
#
#  Score of gcv_out prediction 45.51%
#         Best parameters in inner CV: {'oversample__sampling_strategy': 'auto', 'm7__n_estimators': 300, 'm7__max_depth': 3, 'm7__learning_rate': 0.01, 'import__max_features': 10}
#        Score of best estimator prediction 45.51%
#
#
#  Score of gcv_out prediction 40.47%
#         Best parameters in inner CV: {'oversample__sampling_strategy': 'auto', 'm7__n_estimators': 300, 'm7__max_depth': 3, 'm7__learning_rate': 0.01, 'import__max_features': 10}
#        Score of best estimator prediction 40.47%
#
#
#  Score of gcv_out prediction 42.50%
#         Best parameters in inner CV: {'oversample__sampling_strategy': 'auto', 'm7__n_estimators': 300, 'm7__max_depth': 3, 'm7__learning_rate': 0.02, 'import__max_features': 8}
#        Score of best estimator prediction 42.50%
#
#
#  Score of gcv_out prediction 43.54%
#         Best parameters in inner CV: {'oversample__sampling_strategy': 'auto', 'm7__n_estimators': 300, 'm7__max_depth': 5, 'm7__learning_rate': 0.01, 'import__max_features': 10}
#        Score of best estimator prediction 43.54%
#
#     Outer Loop:
#         balanced accuracy score 43.47% +/- 7.43
# _._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._.
#
#   GradientBoostingClassifier
#
#
#  Score of gcv_out prediction 52.93%
#         Best parameters in inner CV: {'oversample__sampling_strategy': 'auto', 'm8__n_estimators': 50, 'm8__max_depth': 3, 'm8__learning_rate': 0.01, 'import__max_features': 4}
#        Score of best estimator prediction 52.93%
#
#
#  Score of gcv_out prediction 43.96%
#         Best parameters in inner CV: {'oversample__sampling_strategy': 'auto', 'm8__n_estimators': 50, 'm8__max_depth': 8, 'm8__learning_rate': 0.01, 'import__max_features': 6}
#        Score of best estimator prediction 43.96%
#
#
#  Score of gcv_out prediction 43.16%
#         Best parameters in inner CV: {'oversample__sampling_strategy': 'auto', 'm8__n_estimators': 50, 'm8__max_depth': 3, 'm8__learning_rate': 0.02, 'import__max_features': 10}
#        Score of best estimator prediction 43.16%
#
#
#  Score of gcv_out prediction 41.48%
#         Best parameters in inner CV: {'oversample__sampling_strategy': 'auto', 'm8__n_estimators': 100, 'm8__max_depth': 3, 'm8__learning_rate': 0.01, 'import__max_features': 8}
#        Score of best estimator prediction 41.48%
#
#
#  Score of gcv_out prediction 36.02%
#         Best parameters in inner CV: {'oversample__sampling_strategy': 'auto', 'm8__n_estimators': 300, 'm8__max_depth': 3, 'm8__learning_rate': 0.01, 'import__max_features': 8}
#        Score of best estimator prediction 36.02%
#
#
#  Score of gcv_out prediction 35.67%
#         Best parameters in inner CV: {'oversample__sampling_strategy': 'auto', 'm8__n_estimators': 300, 'm8__max_depth': 5, 'm8__learning_rate': 0.02, 'import__max_features': 6}
#        Score of best estimator prediction 35.67%
#
#
#  Score of gcv_out prediction 47.49%
#         Best parameters in inner CV: {'oversample__sampling_strategy': 'auto', 'm8__n_estimators': 100, 'm8__max_depth': 3, 'm8__learning_rate': 0.02, 'import__max_features': 6}
#        Score of best estimator prediction 47.49%
#
#
#  Score of gcv_out prediction 42.66%
#         Best parameters in inner CV: {'oversample__sampling_strategy': 'auto', 'm8__n_estimators': 300, 'm8__max_depth': 3, 'm8__learning_rate': 0.02, 'import__max_features': 6}
#        Score of best estimator prediction 42.66%
#
#
#  Score of gcv_out prediction 37.40%
#         Best parameters in inner CV: {'oversample__sampling_strategy': 'auto', 'm8__n_estimators': 400, 'm8__max_depth': 5, 'm8__learning_rate': 0.01, 'import__max_features': 6}
#        Score of best estimator prediction 37.40%
#
#
#  Score of gcv_out prediction 40.93%
#         Best parameters in inner CV: {'oversample__sampling_strategy': 'auto', 'm8__n_estimators': 100, 'm8__max_depth': 5, 'm8__learning_rate': 0.01, 'import__max_features': 8}
#        Score of best estimator prediction 40.93%
#
#     Outer Loop:
#         balanced accuracy score 43.29% +/- 7.15

# %% [markdown]
# Comparing scores of different models

# %% [markdown]
# Baes on above modeling results, the best model is model six. So Now I repeat nested cross validation for the best model.

# %%
gcv_model_select = RandomizedSearchCV(estimator=pipe2,
                                param_distributions=par2,
                                scoring='balanced_accuracy',
                                n_jobs=-1,
                                cv=inner_cv,
                                verbose=1,
                                n_iter=30,
                                refit=True)

for train_idx, test_idx in outer_cv.split(X_train, y_train): 
    gcv_model_select.fit(X_train[train_idx], y_train[train_idx]) # run inner loop hyperparam tuning
   

    print('\n       Best balanced accuracy score in inner CV %.2f%%' % (100*(gcv_model_select.best_score_)))
    print('        Best parameters in inner CV:', gcv_model_select.best_params_)
    print('       Best score in test data of outer CV %.2f%%' % (gcv_model_select.best_estimator_.score(X_train[test_idx], y_train[test_idx])*100))
        

m=gcv_model_select.best_estimator_.fit(X_train, y_train)
print('Best CV accuracy: %.2f%%' % (gcv_model_select.best_score_*100))
print('Best parameters:', gcv_model_select.best_params_)
print('test accuracy: %.2f%%' % (balanced_accuracy_score(y_test, m.predict(X_test))*100))
print('train accuracy: %.2f%%' % (balanced_accuracy_score(y_train, m.predict(X_train))*100))
con(m.predict(X_test),y_test)
# Out:
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
#
#        Best balanced accuracy score in inner CV 58.43%
#         Best parameters in inner CV: {'oversample__sampling_strategy': 'auto', 'm2__n_estimators': 100, 'm2__learning_rate': 0.01, 'import__max_features': 8}
#        Best score in test data of outer CV 60.42%
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
#
#        Best balanced accuracy score in inner CV 55.85%
#         Best parameters in inner CV: {'oversample__sampling_strategy': 'auto', 'm2__n_estimators': 100, 'm2__learning_rate': 0.001, 'import__max_features': 10}
#        Best score in test data of outer CV 44.21%
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
#
#        Best balanced accuracy score in inner CV 55.18%
#         Best parameters in inner CV: {'oversample__sampling_strategy': 'auto', 'm2__n_estimators': 50, 'm2__learning_rate': 0.01, 'import__max_features': 10}
#        Best score in test data of outer CV 37.89%
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
#
#        Best balanced accuracy score in inner CV 59.11%
#         Best parameters in inner CV: {'oversample__sampling_strategy': 'auto', 'm2__n_estimators': 400, 'm2__learning_rate': 0.001, 'import__max_features': 10}
#        Best score in test data of outer CV 44.21%
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
#
#        Best balanced accuracy score in inner CV 59.19%
#         Best parameters in inner CV: {'oversample__sampling_strategy': 'auto', 'm2__n_estimators': 200, 'm2__learning_rate': 0.001, 'import__max_features': 10}
#        Best score in test data of outer CV 33.68%
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
#
#        Best balanced accuracy score in inner CV 58.18%
#         Best parameters in inner CV: {'oversample__sampling_strategy': 'auto', 'm2__n_estimators': 100, 'm2__learning_rate': 0.001, 'import__max_features': 10}
#        Best score in test data of outer CV 42.11%
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
#
#        Best balanced accuracy score in inner CV 55.89%
#         Best parameters in inner CV: {'oversample__sampling_strategy': 'auto', 'm2__n_estimators': 200, 'm2__learning_rate': 0.001, 'import__max_features': 4}
#        Best score in test data of outer CV 41.05%
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
#
#        Best balanced accuracy score in inner CV 60.95%
#         Best parameters in inner CV: {'oversample__sampling_strategy': 'auto', 'm2__n_estimators': 400, 'm2__learning_rate': 0.001, 'import__max_features': 8}
#        Best score in test data of outer CV 44.21%
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
#
#        Best balanced accuracy score in inner CV 54.99%
#         Best parameters in inner CV: {'oversample__sampling_strategy': 'auto', 'm2__n_estimators': 100, 'm2__learning_rate': 0.001, 'import__max_features': 6}
#        Best score in test data of outer CV 37.89%
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
#
#        Best balanced accuracy score in inner CV 62.92%
#         Best parameters in inner CV: {'oversample__sampling_strategy': 'auto', 'm2__n_estimators': 50, 'm2__learning_rate': 0.1, 'import__max_features': 8}
#        Best score in test data of outer CV 46.32%
# Best CV accuracy: 62.92%
# Best parameters: {'oversample__sampling_strategy': 'auto', 'm2__n_estimators': 50, 'm2__learning_rate': 0.1, 'import__max_features': 8}
# test accuracy: 50.36%
# train accuracy: 67.39%
#         low  medium  high
# low     135      71     0
# medium   50      86     3
# high      7      54     2

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, m.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.66      0.70      0.68       192
#            1       0.62      0.41      0.49       211
#            2       0.03      0.40      0.06         5
#
#     accuracy                           0.55       408
#    macro avg       0.44      0.50      0.41       408
# weighted avg       0.63      0.55      0.57       408

# %%
from sklearn.metrics import balanced_accuracy_score
print("Balaced accuracy is : %.2f%%" %(balanced_accuracy_score(y_test, m.
predict(X_test))*100))
# Out:
# Balaced accuracy is : 50.36%
