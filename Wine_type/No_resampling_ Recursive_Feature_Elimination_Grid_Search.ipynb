# %% [markdown]
# Predicting wine type: Here I use Recursive Feature Elimination method for Feature selection and Grid search for searching method.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
white_wine=pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-white.csv", sep=';')
red_wine=pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-red.csv", sep=';')
print(red_wine.shape, white_wine.shape)
# Out:
# (1599, 12) (4898, 12)

# %% [markdown]
# Merge two wine datasets

# %%
white_wine["wine_type"]=0
red_wine["wine_type"]=1
red_wine=red_wine.drop_duplicates()
white_wine=white_wine.drop_duplicates()
total_wine=pd.concat([white_wine, red_wine])
total_wine.index=range(len(total_wine))
total_wine.hist(figsize=(12,6),layout=(3,5))
total_wine
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0             0.270         0.36            20.7      0.045
# 1               6.3             0.300         0.34             1.6      0.049
# 2               8.1             0.280         0.40             6.9      0.050
# 3               7.2             0.230         0.32             8.5      0.058
# 4               6.2             0.320         0.16             7.0      0.045
# ...             ...               ...          ...             ...        ...
# 5315            6.8             0.620         0.08             1.9      0.068
# 5316            6.2             0.600         0.08             2.0      0.090
# 5317            5.9             0.550         0.10             2.2      0.062
# 5318            5.9             0.645         0.12             2.0      0.075
# 5319            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    45.0                 170.0  1.00100  3.00       0.45
# 1                    14.0                 132.0  0.99400  3.30       0.49
# 2                    30.0                  97.0  0.99510  3.26       0.44
# 3                    47.0                 186.0  0.99560  3.19       0.40
# 4                    30.0                 136.0  0.99490  3.18       0.47
# ...                   ...                   ...      ...   ...        ...
# 5315                 28.0                  38.0  0.99651  3.42       0.82
# 5316                 32.0                  44.0  0.99490  3.45       0.58
# 5317                 39.0                  51.0  0.99512  3.52       0.76
# 5318                 32.0                  44.0  0.99547  3.57       0.71
# 5319                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality  wine_type
# 0         8.8        6          0
# 1         9.5        6          0
# 2        10.1        6          0
# 3         9.9        6          0
# 4         9.6        6          0
# ...       ...      ...        ...
# 5315      9.5        6          1
# 5316     10.5        5          1
# 5317     11.2        6          1
# 5318     10.2        5          1
# 5319     11.0        6          1
#
# [5320 rows x 13 columns]

# %% [markdown]
# As it is seen above most of features are right-skewed. I transform the data to log to bring the destribution of data closeer to normal.

# %%
total_wine_t=np.log((total_wine[total_wine.columns[:-1]])+0.00005)
total_wine_t["wine_type"]=total_wine["wine_type"]
total_wine_t.hist(figsize=(12,6),layout=(3,5))
# Out:
# array([[<AxesSubplot:title={'center':'fixed acidity'}>,
#         <AxesSubplot:title={'center':'volatile acidity'}>,
#         <AxesSubplot:title={'center':'citric acid'}>,
#         <AxesSubplot:title={'center':'residual sugar'}>,
#         <AxesSubplot:title={'center':'chlorides'}>],
#        [<AxesSubplot:title={'center':'free sulfur dioxide'}>,
#         <AxesSubplot:title={'center':'total sulfur dioxide'}>,
#         <AxesSubplot:title={'center':'density'}>,
#         <AxesSubplot:title={'center':'pH'}>,
#         <AxesSubplot:title={'center':'sulphates'}>],
#        [<AxesSubplot:title={'center':'alcohol'}>,
#         <AxesSubplot:title={'center':'quality'}>,
#         <AxesSubplot:title={'center':'wine_type'}>, <AxesSubplot:>,
#         <AxesSubplot:>]], dtype=object)

# %% [markdown]
# Plot pie chart to see how many red and white wines are there in the data set

# %%
plt.pie(total_wine_t['wine_type'].value_counts(), labels=total_wine_t['wine_type'].unique(), autopct='%.2f')
# Out:
# ([<matplotlib.patches.Wedge at 0x7fb277684a00>,
#   <matplotlib.patches.Wedge at 0x7fb277956160>],
#  [Text(-0.7643837219024623, 0.7910230879630122, '0'),
#   Text(0.7643836478415325, -0.7910231595297779, '1')],
#  [Text(-0.4169365755831612, 0.4314671388889157, '74.45'),
#   Text(0.41693653518629037, -0.43146717792533335, '25.55')])

# %%
total_wine_t.index=range(len(total_wine_t))

# %% [markdown]
# Split data

# %%
from sklearn.model_selection import train_test_split
x, y=total_wine_t[total_wine_t.columns[:-1]], total_wine_t[total_wine_t.columns[-1]]
x=np.array(x)
y=np.array(y)
X_train,X_test,y_train,y_test=train_test_split(x,y, test_size=0.3,shuffle=True, random_state=42,stratify=y)

# %% [markdown]
# Create pipelines to use in nested cross validation

# %%
from sklearn.ensemble import  RandomForestClassifier, AdaBoostClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from xgboost import XGBClassifier as Xgb
from sklearn.neighbors import KNeighborsClassifier
from lightgbm import LGBMClassifier as LighGB
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.model_selection import GridSearchCV
from sklearn.feature_selection import RFE
from sklearn.metrics import matthews_corrcoef, f1_score, confusion_matrix, balanced_accuracy_score
from sklearn.pipeline import Pipeline
from sklearn.model_selection import cross_validate, StratifiedKFold, RepeatedStratifiedKFold
from sklearn.model_selection import learning_curve

# initiakising classifiers

m1 = LogisticRegression(multi_class='multinomial',
                          solver='newton-cg',
                          random_state=1)
m2 = AdaBoostClassifier(random_state=1)
m3 = DecisionTreeClassifier(random_state=1)
m4 = LighGB(random_state=1)
m5 = RandomForestClassifier(random_state=1)

# Building the pipelines
pipe1 = Pipeline([('rfe', RFE(estimator=m1)),
                  ('m1', m1)])

pipe2 = Pipeline([('rfe', RFE(estimator=m2)),
                  ('m2', m2)])
                
pipe3=Pipeline([('rfe', RFE(estimator=m3)),
                  ('m3', m3)])

pipe4 = Pipeline([('rfe', RFE(estimator=m4)),
                  ('m4', m4)])
pipe5 = Pipeline([('rfe', RFE(estimator=m5)),
                  ('m5', m5)])



# Setting up the parameter grids
par1 = [{"rfe__n_features_to_select": [6,8,10], 'm1__penalty': ['l2']
                ,'m1__C': np.power(10., np.arange(-4, 4))}]

par2 = [{"rfe__n_features_to_select": [6,8,10],"m2__n_estimators":[50,100,200,600], 
"m2__learning_rate": [0.01,0.001,0.1]}]

par3 = [{ "rfe__n_features_to_select": [6,8,10], "m3__criterion": ["gini", "entropy"],
"m3__splitter": ["best", "random"], "m3__max_depth": [None, 5,7,12]}]  

par4 = [{"rfe__n_features_to_select": [6,7,8,9], 
"m4__max_depth": [-1,5,8], "m4__n_estimators": [100,300,500],
"m4__learning_rate": [0.01,0.1], "m4__subsample_for_bin":[500,10000,200000]}]

par5 = [{"rfe__n_features_to_select": [6,8,10],  "m5__max_depth": [None,5,8,12],
              "m5__n_estimators" :[100,300,600],
              "m5__criterion": ["gini","entropy"]}]

# %% [markdown]
# Creat inner CV

# %%
pipe=[pipe1,pipe2,pipe3,pipe4,pipe5]
par_grid=[par1,par2,par3,par4,par5]
gcv_all=[]
inner_cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=1)
for i in range(len(pipe)):
    gcv = GridSearchCV(estimator=pipe[i],
                        param_grid=par_grid[i],
                        scoring='f1',
                        n_jobs=-1,
                        cv=inner_cv,
                        verbose=0,
                        refit=True)
    gcv_all.append(gcv)

# %% [markdown]
# Function for ploting learning curves

# %%
# Plot learning curve
def plot_learning_curve(estimator, title, X, y, ylim=None, cv=None,
                        n_jobs=-1, train_sizes=np.linspace(.1, 1.0, 5)):
    """
    Generate a simple plot of the test and traning learning curve.

    Parameters
    ----------
    estimator : object type that implements the "fit" and "predict" methods
        An object of that type which is cloned for each validation.

    title : string
        Title for the chart.

    X : array-like, shape (n_samples, n_features)
        Training vector, where n_samples is the number of samples and
        n_features is the number of features.

    y : array-like, shape (n_samples) or (n_samples, n_features), optional
        Target relative to X for classification or regression;
        None for unsupervised learning.

    ylim : tuple, shape (ymin, ymax), optional
        Defines minimum and maximum yvalues plotted.

    cv : integer, cross-validation generator, optional
        If an integer is passed, it is the number of folds (defaults to 3).
        Specific cross-validation objects can be passed, see
        sklearn.cross_validation module for the list of possible objects

    n_jobs : integer, optional
        Number of jobs to run in parallel (default 1).
        
    x1 = np.linspace(0, 10, 8, endpoint=True) produces
        8 evenly spaced points in the range 0 to 10
    """
    
    
    plt.figure()
    plt.title(title)
    if ylim is not None:
        plt.ylim(*ylim)
        
    plt.xlabel("Training examples")
    plt.ylabel("Score")
    train_sizes, train_scores, test_scores = learning_curve(
        estimator, X, y, cv=cv, n_jobs=n_jobs, train_sizes=train_sizes, scoring= "balanced_accuracy")
    train_scores_mean = np.mean(train_scores, axis=1)
    train_scores_std = np.std(train_scores, axis=1)
    test_scores_mean = np.mean(test_scores, axis=1)
    test_scores_std = np.std(test_scores, axis=1)
    plt.grid()

    plt.fill_between(train_sizes, train_scores_mean - train_scores_std,
                     train_scores_mean + train_scores_std, alpha=0.1,
                     color="r")
    plt.fill_between(train_sizes, test_scores_mean - test_scores_std,
                     test_scores_mean + test_scores_std, alpha=0.1, color="g")
    plt.plot(train_sizes, train_scores_mean, 'o-', color="r",
             label="Training score")
    plt.plot(train_sizes, test_scores_mean, 'o-', color="g",
             label="Cross-validation score")

    plt.legend(loc="best")
    return plt

# %% [markdown]
# Out CV + plotting learning curves

# %%
final_scores = []
final_mean_score=[]
final_std_score=[]

outer_cv = StratifiedKFold(n_splits=10, shuffle=True, random_state=1)
name=['LogisticRegression', 'AdaBoostClassifier','DecisionTreeClassifier'
,'LighGB', 'RandomForestClassifier'] 
count=0   
for gcv_out in gcv_all:  
    print(80*'_.')
    print('\n ', name[count] )  
    for train_idx, test_idx in outer_cv.split(X_train, y_train): 
        gcv_out.fit(X_train[train_idx], y_train[train_idx]) # run inner loop hyperparam tuning
        pr=gcv_out.predict(X_train[test_idx]) 
        print('\n\n Score of gcv_out prediction %.2f%%' % ((balanced_accuracy_score(pr, y_train[test_idx]))*100))


        print('        Best parameters in inner CV:', gcv_out.best_params_)
        
    
        final_scores.append((balanced_accuracy_score(gcv_out.best_estimator_.predict(X_train[test_idx]), y_train[test_idx])*100)) 
  
        print('       Score of best estimator prediction %.2f%%' % final_scores[-1])
        model=gcv_out.best_estimator_.fit(X_train[train_idx], y_train[train_idx])



    
    print('\n    Outer Loop:')
    print('        balanced accuracy score %.2f%% +/- %.2f' % 
                (np.mean(final_scores) , np.std(final_scores) ))
    final_mean_score.append(np.mean(final_scores) )
    final_std_score.append(np.std(final_scores) )

    plot_learning_curve(estimator = gcv_out.best_estimator_,title = "{} learning curve ".format(name[count]),
                    X = X_train, y = y_train, cv = 5)
    plt.show()
    train_sizes, train_scores, test_scores = learning_curve(
    gcv_out.best_estimator_, X = X_train, y = y_train, cv=5, n_jobs=-1, train_sizes=np.linspace(.1, 1.0, 5), scoring= "balanced_accuracy")
 
    count+=1
# Out:
# _._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._.
#
#   LogisticRegression
#
#
#  Score of gcv_out prediction 99.64%
#         Best parameters in inner CV: {'m1__C': 100.0, 'm1__penalty': 'l2', 'rfe__n_features_to_select': 8}
#        Score of best estimator prediction 99.64%
#
#
#  Score of gcv_out prediction 98.59%
#         Best parameters in inner CV: {'m1__C': 1000.0, 'm1__penalty': 'l2', 'rfe__n_features_to_select': 8}
#        Score of best estimator prediction 98.59%
#
#
#  Score of gcv_out prediction 96.39%
#         Best parameters in inner CV: {'m1__C': 1000.0, 'm1__penalty': 'l2', 'rfe__n_features_to_select': 8}
#        Score of best estimator prediction 96.39%
#
#
#  Score of gcv_out prediction 98.59%
#         Best parameters in inner CV: {'m1__C': 1000.0, 'm1__penalty': 'l2', 'rfe__n_features_to_select': 10}
#        Score of best estimator prediction 98.59%
#
#
#  Score of gcv_out prediction 98.78%
#         Best parameters in inner CV: {'m1__C': 1000.0, 'm1__penalty': 'l2', 'rfe__n_features_to_select': 8}
#        Score of best estimator prediction 98.78%
#
#
#  Score of gcv_out prediction 98.40%
#         Best parameters in inner CV: {'m1__C': 100.0, 'm1__penalty': 'l2', 'rfe__n_features_to_select': 8}
#        Score of best estimator prediction 98.40%
#
#
#  Score of gcv_out prediction 99.48%
#         Best parameters in inner CV: {'m1__C': 1000.0, 'm1__penalty': 'l2', 'rfe__n_features_to_select': 8}
#        Score of best estimator prediction 99.48%
#
#
#  Score of gcv_out prediction 99.64%
#         Best parameters in inner CV: {'m1__C': 1000.0, 'm1__penalty': 'l2', 'rfe__n_features_to_select': 10}
#        Score of best estimator prediction 99.64%
#
#
#  Score of gcv_out prediction 98.27%
#         Best parameters in inner CV: {'m1__C': 1000.0, 'm1__penalty': 'l2', 'rfe__n_features_to_select': 10}
#        Score of best estimator prediction 98.27%
#
#
#  Score of gcv_out prediction 97.37%
#         Best parameters in inner CV: {'m1__C': 10.0, 'm1__penalty': 'l2', 'rfe__n_features_to_select': 10}
#        Score of best estimator prediction 97.37%
#
#     Outer Loop:
#         balanced accuracy score 98.51% +/- 0.97
# _._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._.
#
#   AdaBoostClassifier
#
#
#  Score of gcv_out prediction 99.30%
#         Best parameters in inner CV: {'m2__learning_rate': 0.1, 'm2__n_estimators': 600, 'rfe__n_features_to_select': 10}
#        Score of best estimator prediction 99.30%
#
#
#  Score of gcv_out prediction 98.93%
#         Best parameters in inner CV: {'m2__learning_rate': 0.1, 'm2__n_estimators': 600, 'rfe__n_features_to_select': 10}
#        Score of best estimator prediction 98.93%
#
#
#  Score of gcv_out prediction 98.59%
#         Best parameters in inner CV: {'m2__learning_rate': 0.1, 'm2__n_estimators': 600, 'rfe__n_features_to_select': 10}
#        Score of best estimator prediction 98.59%
#
#
#  Score of gcv_out prediction 99.47%
#         Best parameters in inner CV: {'m2__learning_rate': 0.1, 'm2__n_estimators': 600, 'rfe__n_features_to_select': 10}
#        Score of best estimator prediction 99.47%
#
#
#  Score of gcv_out prediction 98.40%
#         Best parameters in inner CV: {'m2__learning_rate': 0.1, 'm2__n_estimators': 600, 'rfe__n_features_to_select': 10}
#        Score of best estimator prediction 98.40%
#
#
#  Score of gcv_out prediction 99.11%
#         Best parameters in inner CV: {'m2__learning_rate': 0.1, 'm2__n_estimators': 600, 'rfe__n_features_to_select': 8}
#        Score of best estimator prediction 99.11%
#
#
#  Score of gcv_out prediction 100.00%
#         Best parameters in inner CV: {'m2__learning_rate': 0.1, 'm2__n_estimators': 600, 'rfe__n_features_to_select': 10}
#        Score of best estimator prediction 100.00%
#
#
#  Score of gcv_out prediction 99.82%
#         Best parameters in inner CV: {'m2__learning_rate': 0.1, 'm2__n_estimators': 600, 'rfe__n_features_to_select': 10}
#        Score of best estimator prediction 99.82%
#
#
#  Score of gcv_out prediction 99.48%
#         Best parameters in inner CV: {'m2__learning_rate': 0.1, 'm2__n_estimators': 600, 'rfe__n_features_to_select': 10}
#        Score of best estimator prediction 99.48%
#
#
#  Score of gcv_out prediction 98.59%
#         Best parameters in inner CV: {'m2__learning_rate': 0.1, 'm2__n_estimators': 600, 'rfe__n_features_to_select': 10}
#        Score of best estimator prediction 98.59%
#
#     Outer Loop:
#         balanced accuracy score 98.84% +/- 0.84
# _._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._.
#
#   DecisionTreeClassifier
#
#
#  Score of gcv_out prediction 96.70%
#         Best parameters in inner CV: {'m3__criterion': 'entropy', 'm3__max_depth': 12, 'm3__splitter': 'random', 'rfe__n_features_to_select': 10}
#        Score of best estimator prediction 96.70%
#
#
#  Score of gcv_out prediction 96.18%
#         Best parameters in inner CV: {'m3__criterion': 'entropy', 'm3__max_depth': 7, 'm3__splitter': 'best', 'rfe__n_features_to_select': 10}
#        Score of best estimator prediction 96.18%
#
#
#  Score of gcv_out prediction 95.45%
#         Best parameters in inner CV: {'m3__criterion': 'gini', 'm3__max_depth': None, 'm3__splitter': 'random', 'rfe__n_features_to_select': 8}
#        Score of best estimator prediction 95.45%
#
#
#  Score of gcv_out prediction 99.47%
#         Best parameters in inner CV: {'m3__criterion': 'entropy', 'm3__max_depth': None, 'm3__splitter': 'random', 'rfe__n_features_to_select': 10}
#        Score of best estimator prediction 99.47%
#
#
#  Score of gcv_out prediction 97.29%
#         Best parameters in inner CV: {'m3__criterion': 'entropy', 'm3__max_depth': 7, 'm3__splitter': 'best', 'rfe__n_features_to_select': 10}
#        Score of best estimator prediction 97.29%
#
#
#  Score of gcv_out prediction 95.92%
#         Best parameters in inner CV: {'m3__criterion': 'entropy', 'm3__max_depth': 12, 'm3__splitter': 'best', 'rfe__n_features_to_select': 8}
#        Score of best estimator prediction 95.92%
#
#
#  Score of gcv_out prediction 97.29%
#         Best parameters in inner CV: {'m3__criterion': 'entropy', 'm3__max_depth': 7, 'm3__splitter': 'best', 'rfe__n_features_to_select': 6}
#        Score of best estimator prediction 97.29%
#
#
#  Score of gcv_out prediction 98.02%
#         Best parameters in inner CV: {'m3__criterion': 'entropy', 'm3__max_depth': None, 'm3__splitter': 'random', 'rfe__n_features_to_select': 10}
#        Score of best estimator prediction 98.02%
#
#
#  Score of gcv_out prediction 97.88%
#         Best parameters in inner CV: {'m3__criterion': 'gini', 'm3__max_depth': 12, 'm3__splitter': 'best', 'rfe__n_features_to_select': 8}
#        Score of best estimator prediction 97.88%
#
#
#  Score of gcv_out prediction 99.29%
#         Best parameters in inner CV: {'m3__criterion': 'entropy', 'm3__max_depth': 7, 'm3__splitter': 'best', 'rfe__n_features_to_select': 8}
#        Score of best estimator prediction 99.29%
#
#     Outer Loop:
#         balanced accuracy score 98.34% +/- 1.23
# _._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._.
#
#   LighGB
#
#
#  Score of gcv_out prediction 99.11%
#         Best parameters in inner CV: {'m4__learning_rate': 0.1, 'm4__max_depth': 8, 'm4__n_estimators': 100, 'm4__subsample_for_bin': 10000, 'rfe__n_features_to_select': 8}
#        Score of best estimator prediction 99.11%
#
#
#  Score of gcv_out prediction 99.11%
#         Best parameters in inner CV: {'m4__learning_rate': 0.1, 'm4__max_depth': 5, 'm4__n_estimators': 500, 'm4__subsample_for_bin': 10000, 'rfe__n_features_to_select': 9}
#        Score of best estimator prediction 99.11%
#
#
#  Score of gcv_out prediction 99.29%
#         Best parameters in inner CV: {'m4__learning_rate': 0.1, 'm4__max_depth': 5, 'm4__n_estimators': 300, 'm4__subsample_for_bin': 10000, 'rfe__n_features_to_select': 9}
#        Score of best estimator prediction 99.29%
#
#
#  Score of gcv_out prediction 99.64%
#         Best parameters in inner CV: {'m4__learning_rate': 0.1, 'm4__max_depth': 5, 'm4__n_estimators': 300, 'm4__subsample_for_bin': 10000, 'rfe__n_features_to_select': 9}
#        Score of best estimator prediction 99.64%
#
#
#  Score of gcv_out prediction 99.11%
#         Best parameters in inner CV: {'m4__learning_rate': 0.1, 'm4__max_depth': 5, 'm4__n_estimators': 500, 'm4__subsample_for_bin': 10000, 'rfe__n_features_to_select': 8}
#        Score of best estimator prediction 99.11%
#
#
#  Score of gcv_out prediction 99.11%
#         Best parameters in inner CV: {'m4__learning_rate': 0.1, 'm4__max_depth': 5, 'm4__n_estimators': 500, 'm4__subsample_for_bin': 500, 'rfe__n_features_to_select': 8}
#        Score of best estimator prediction 99.11%
#
#
#  Score of gcv_out prediction 99.48%
#         Best parameters in inner CV: {'m4__learning_rate': 0.1, 'm4__max_depth': 8, 'm4__n_estimators': 500, 'm4__subsample_for_bin': 500, 'rfe__n_features_to_select': 8}
#        Score of best estimator prediction 99.48%
#
#
#  Score of gcv_out prediction 99.46%
#         Best parameters in inner CV: {'m4__learning_rate': 0.1, 'm4__max_depth': -1, 'm4__n_estimators': 500, 'm4__subsample_for_bin': 10000, 'rfe__n_features_to_select': 8}
#        Score of best estimator prediction 99.46%
#
#
#  Score of gcv_out prediction 99.82%
#         Best parameters in inner CV: {'m4__learning_rate': 0.1, 'm4__max_depth': 5, 'm4__n_estimators': 300, 'm4__subsample_for_bin': 10000, 'rfe__n_features_to_select': 9}
#        Score of best estimator prediction 99.82%
#
#
#  Score of gcv_out prediction 99.29%
#         Best parameters in inner CV: {'m4__learning_rate': 0.1, 'm4__max_depth': 5, 'm4__n_estimators': 500, 'm4__subsample_for_bin': 10000, 'rfe__n_features_to_select': 8}
#        Score of best estimator prediction 99.29%
#
#     Outer Loop:
#         balanced accuracy score 98.59% +/- 1.16
# _._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._.
#
#   RandomForestClassifier
#
#
#  Score of gcv_out prediction 99.64%
#         Best parameters in inner CV: {'m5__criterion': 'entropy', 'm5__max_depth': 8, 'm5__n_estimators': 600, 'rfe__n_features_to_select': 10}
#        Score of best estimator prediction 99.64%
#
#
#  Score of gcv_out prediction 99.64%
#         Best parameters in inner CV: {'m5__criterion': 'gini', 'm5__max_depth': 8, 'm5__n_estimators': 100, 'rfe__n_features_to_select': 10}
#        Score of best estimator prediction 99.64%
#
#
#  Score of gcv_out prediction 98.93%
#         Best parameters in inner CV: {'m5__criterion': 'entropy', 'm5__max_depth': 8, 'm5__n_estimators': 100, 'rfe__n_features_to_select': 10}
#        Score of best estimator prediction 98.93%
#
#
#  Score of gcv_out prediction 99.47%
#         Best parameters in inner CV: {'m5__criterion': 'entropy', 'm5__max_depth': None, 'm5__n_estimators': 600, 'rfe__n_features_to_select': 10}
#        Score of best estimator prediction 99.47%
#
#
#  Score of gcv_out prediction 99.11%
#         Best parameters in inner CV: {'m5__criterion': 'entropy', 'm5__max_depth': None, 'm5__n_estimators': 600, 'rfe__n_features_to_select': 10}
#        Score of best estimator prediction 99.11%
#
#
#  Score of gcv_out prediction 99.11%
#         Best parameters in inner CV: {'m5__criterion': 'gini', 'm5__max_depth': None, 'm5__n_estimators': 100, 'rfe__n_features_to_select': 10}
#        Score of best estimator prediction 99.11%
#
#
#  Score of gcv_out prediction 99.82%
#         Best parameters in inner CV: {'m5__criterion': 'gini', 'm5__max_depth': 12, 'm5__n_estimators': 100, 'rfe__n_features_to_select': 10}
#        Score of best estimator prediction 99.82%
#
#
#  Score of gcv_out prediction 99.29%
#         Best parameters in inner CV: {'m5__criterion': 'gini', 'm5__max_depth': 12, 'm5__n_estimators': 300, 'rfe__n_features_to_select': 10}
#        Score of best estimator prediction 99.29%
#
#
#  Score of gcv_out prediction 99.82%
#         Best parameters in inner CV: {'m5__criterion': 'entropy', 'm5__max_depth': 8, 'm5__n_estimators': 100, 'rfe__n_features_to_select': 10}
#        Score of best estimator prediction 99.82%
#
#
#  Score of gcv_out prediction 98.74%
#         Best parameters in inner CV: {'m5__criterion': 'entropy', 'm5__max_depth': 8, 'm5__n_estimators': 100, 'rfe__n_features_to_select': 8}
#        Score of best estimator prediction 98.74%
#
#     Outer Loop:
#         balanced accuracy score 98.75% +/- 1.09

# %% [markdown]
# Comparing scores of different models

# %%
def con(y_test,pred_rfc):
    labels = np.unique(y_test)
    a = confusion_matrix(y_test, pred_rfc)
    a = pd.DataFrame(a, index=("White-wine", "Red_wine"), columns=("White_wine", "Red_wine"))
    display(a)

# %% [markdown]
# Baes on above modeling results, the best model is model two (AdaBoostClassifier). So Now I repeat nested cross validation for the best model.

# %%
from sklearn.metrics import balanced_accuracy_score
gcv_model_select = GridSearchCV(estimator=pipe2,
                                param_grid=par2,
                                scoring='balanced_accuracy',
                                n_jobs=-1,
                                cv=inner_cv,
                                verbose=1,
                                refit=True)

for train_idx, test_idx in outer_cv.split(X_train, y_train): 
    gcv_model_select.fit(X_train[train_idx], y_train[train_idx]) # run inner loop hyperparam tuning
   

    print('\n       Best balanced accuracy score in inner CV %.2f%%' % (100*(gcv_model_select.best_score_)))
    print('        Best parameters in inner CV:', gcv_model_select.best_params_)
    print('       Best score in test data of outer CV %.2f%%' % (gcv_model_select.best_estimator_.score(X_train[test_idx], y_train[test_idx])*100))
        

m=gcv_model_select.best_estimator_.fit(X_train, y_train)
m=gcv_model_select.best_estimator_.fit(X_train, y_train)
print('Best CV accuracy: %.2f%%' % (gcv_model_select.best_score_*100))
print('Best parameters:', gcv_model_select.best_params_)
print('test accuracy: %.2f%%' % (balanced_accuracy_score(y_test, m.predict(X_test))*100))
print('train accuracy: %.2f%%' % (balanced_accuracy_score(y_train, m.predict(X_train))*100))
con(m.predict(X_test),y_test)
# Out:
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
#
#        Best balanced accuracy score in inner CV 98.88%
#         Best parameters in inner CV: {'m2__learning_rate': 0.1, 'm2__n_estimators': 600, 'rfe__n_features_to_select': 10}
#        Best score in test data of outer CV 99.46%
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
#
#        Best balanced accuracy score in inner CV 99.12%
#         Best parameters in inner CV: {'m2__learning_rate': 0.1, 'm2__n_estimators': 600, 'rfe__n_features_to_select': 10}
#        Best score in test data of outer CV 98.93%
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
#
#        Best balanced accuracy score in inner CV 98.94%
#         Best parameters in inner CV: {'m2__learning_rate': 0.1, 'm2__n_estimators': 600, 'rfe__n_features_to_select': 10}
#        Best score in test data of outer CV 98.93%
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
#
#        Best balanced accuracy score in inner CV 98.89%
#         Best parameters in inner CV: {'m2__learning_rate': 0.1, 'm2__n_estimators': 600, 'rfe__n_features_to_select': 10}
#        Best score in test data of outer CV 99.20%
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
#
#        Best balanced accuracy score in inner CV 98.86%
#         Best parameters in inner CV: {'m2__learning_rate': 0.1, 'm2__n_estimators': 600, 'rfe__n_features_to_select': 10}
#        Best score in test data of outer CV 98.66%
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
#
#        Best balanced accuracy score in inner CV 98.85%
#         Best parameters in inner CV: {'m2__learning_rate': 0.1, 'm2__n_estimators': 600, 'rfe__n_features_to_select': 8}
#        Best score in test data of outer CV 99.19%
# Fitting 5 folds for each of 36 candidates, totalling 180 fits

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, m.predict(X_test)))
# Out:
# MCC is: 98.76%

# %%
from sklearn.metrics import balanced_accuracy_score
print("Balaced accuracy is : %.2f%%" %(balanced_accuracy_score(y_test, m.
predict(X_test))*100))
# Out:
# Balaced accuracy is : 99.48%
